# %%
from waveguide import *

# %%
wg = Ktpwaveguide(λ=1550,w=4,d=5,c=1)

# %%
md = wg.solve(solver='zhu');
# Out:
# filtered 1 modes (1.81951+0j..1.81951+0j) to 1 modes V: V

# %%
Wave.plot(*[Ktpwaveguide(λ=1550,w=4,d=5,c=1,r=p).solve(solver='zhu').indexprofiley() for p in (0,0.5)],fork=0,ylim=(1.8,1.85));
# Out:
# filtered 1 modes (1.81951+0j..1.81951+0j) to 1 modes V: V
# filtered 1 modes (1.81931+0j..1.81931+0j) to 1 modes V: V

# %%
md.mfdx,md.mfdy
# Out:
# (np.float64(6.339209923429662), np.float64(6.77945885721339))

# %%
wg = Ridgewaveguide(λ=1550,step=.1);

# %%
md = wg.solve(solver='zhu',mode=1);
# Out:
# filtered 2 modes (2.12676+0j..2.12285+0j) to 2 modes V: VV

# %%
md.plot(fork=0);

# %%
md.plotindex(fork=0);

# %%
md.neff
# Out:
# np.complex128(2.1267645502826253+0j)

# %%
wg = Rpewaveguide(λ=1550,w=8,sa=1.9,a=23.5,r=24.5);

# %%
md = wg.solve(solver='zhu');
# Out:
# filtered 1 modes (2.14356+0j..2.14356+0j) to 1 modes V: V

# %%
md.plot(fork=0);

# %%
wg = Rpewaveguide(λ=1550,w=8,sa=1.9,a=23.5,r=24.5);

# %%
md = wg.solve(solver='zhu');
# Out:
# filtered 1 modes (2.14356+0j..2.14356+0j) to 1 modes V: V

# %%
qd = wg.qpm(1550,1550)

# %%
qd.Λ
# Out:
# np.float64(16.30337082444942)

# %%
qd.sfgce()
# Out:
# np.float64(468.6144240373183)

# %%
dir(Qpmdata)
# Out:
# ['Type',
#  '__annotations__',
#  '__class__',
#  '__dataclass_fields__',
#  '__dataclass_params__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__match_args__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__replace__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'ce',
#  'conversionefficiency',
#  'deff',
#  'invΛ',
#  'mds',
#  'npsfgce',
#  'npshgce',
#  'overlaparea',
#  'pairrate',
#  'phasematchingangle',
#  'photonconversionP1',
#  'photonconversionP2',
#  'plot',
#  'props',
#  'sell',
#  'sfgce',
#  'shgce',
#  'Λ',
#  'Λtemp',
#  'λ1',
#  'λ2',
#  'λ3']
